# %% [markdown]
# # S1. Red convolucional para MNIST

# %% [markdown]
# Como en la anterior práctica, primero importamos el conjunto de MNIST y lo normalizamos, pero sin convertir las imágenes en vectores unidimensionales, ya que vamos a trabajar con redes convolucionales que explotan la estructura 2D de las imágenes.

# %%
## Importar y normalizar datos

from tensorflow import keras
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

print('training set', x_train.shape)
print('test set', x_test.shape)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize [0..255]-->[0..1]
x_train /= 255
x_test /= 255

# convert class vectors to binary class matrices
num_classes=10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

print('training set', x_train.shape)
print('val set', x_val.shape)
# Out:
# training set (60000, 28, 28)
# test set (10000, 28, 28)
# training set (48000, 28, 28)
# val set (12000, 28, 28)

# %% [markdown]
# ## Modelo base
#  Partiremos de una topología base que toma la red MLP de la última sesión de la primera práctica (dos capas densas de 1024 neuronas), y le incorpora un par de capas convolucionales cada una seguida por average pooling inspirada en la arquitectura LeNet (1998) propuesta por Yann LeCun para MNIST.

# %%
from keras import Sequential
from keras.layers import Input, Conv2D, AveragePooling2D, Flatten, Dense
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

model = Sequential()

model.add(Input((28,28,1)))
model.add(Conv2D(filters=6, kernel_size=(5,5), activation='relu', input_shape=(28,28,1)))
model.add(AveragePooling2D(pool_size=(2,2), strides=2))
model.add(Conv2D(filters=16, kernel_size=(5,5), activation='relu'))
model.add(AveragePooling2D(pool_size=(2,2), strides=2))
model.add(Flatten())
model.add(Dense(units=1024, activation='relu'))
model.add(Dense(units=1024, activation='relu'))
model.add(Dense(units=10, activation = 'softmax'))

opt=Adam(learning_rate=0.01)
model.compile(loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy'])

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001)
checkpoint = ModelCheckpoint(filepath='best_model.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

epochs=25
batch_size=128
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val, y_val),
                    callbacks=[reduce_lr,checkpoint])  

## Cargar el mejor modelo y evaluarlo con el test set
model = keras.models.load_model('best_model.h5')
score = model.evaluate(x_test, y_test, verbose=0)
print(f'Test loss: {score[0]*100:.2f}')
print(f'Test accuracy: {score[1]*100:.2f}')
# Out:
# Epoch 1/25
# 363/375 [============================>.] - ETA: 0s - loss: 0.2691 - accuracy: 0.9154
# Epoch 1: val_accuracy improved from -inf to 0.96725, saving model to best_model.h5
# 375/375 [==============================] - 3s 5ms/step - loss: 0.2650 - accuracy: 0.9167 - val_loss: 0.1119 - val_accuracy: 0.9672 - lr: 0.0100
# Epoch 2/25
# 375/375 [==============================] - ETA: 0s - loss: 0.0964 - accuracy: 0.9714
# Epoch 2: val_accuracy improved from 0.96725 to 0.97667, saving model to best_model.h5
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0964 - accuracy: 0.9714 - val_loss: 0.0780 - val_accuracy: 0.9767 - lr: 0.0100
# Epoch 3/25
# 373/375 [============================>.] - ETA: 0s - loss: 0.0771 - accuracy: 0.9777
# Epoch 3: val_accuracy did not improve from 0.97667
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0771 - accuracy: 0.9777 - val_loss: 0.0908 - val_accuracy: 0.9752 - lr: 0.0100
# Epoch 4/25
# 373/375 [============================>.] - ETA: 0s - loss: 0.0701 - accuracy: 0.9791
# Epoch 4: val_accuracy did not improve from 0.97667
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0701 - accuracy: 0.9791 - val_loss: 0.1151 - val_accuracy: 0.9657 - lr: 0.0100
# Epoch 5/25
# 370/375 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9904
# Epoch 5: val_accuracy improved from 0.97667 to 0.98667, saving model to best_model.h5
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0321 - accuracy: 0.9904 - val_loss: 0.0499 - val_accuracy: 0.9867 - lr: 0.0020
# Epoch 6/25
# 368/375 [============================>.] - ETA: 0s - loss: 0.0180 - accuracy: 0.9945
# Epoch 6: val_accuracy improved from 0.98667 to 0.98733, saving model to best_model.h5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0180 - accuracy: 0.9945 - val_loss: 0.0491 - val_accuracy: 0.9873 - lr: 0.0020
# Epoch 7/25
# 368/375 [============================>.] - ETA: 0s - loss: 0.0130 - accuracy: 0.9961
# Epoch 7: val_accuracy did not improve from 0.98733
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.0531 - val_accuracy: 0.9868 - lr: 0.0020
# Epoch 8/25
# 375/375 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9969
# Epoch 8: val_accuracy improved from 0.98733 to 0.98750, saving model to best_model.h5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.0639 - val_accuracy: 0.9875 - lr: 0.0020
# Epoch 9/25
# 372/375 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9987
# Epoch 9: val_accuracy improved from 0.98750 to 0.98775, saving model to best_model.h5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 0.0576 - val_accuracy: 0.9877 - lr: 4.0000e-04
# Epoch 10/25
# 375/375 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9991
# Epoch 10: val_accuracy improved from 0.98775 to 0.98808, saving model to best_model.h5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0612 - val_accuracy: 0.9881 - lr: 4.0000e-04
# Epoch 11/25
# 363/375 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9993
# Epoch 11: val_accuracy improved from 0.98808 to 0.98842, saving model to best_model.h5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.0609 - val_accuracy: 0.9884 - lr: 8.0000e-05
# Epoch 12/25
# 369/375 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9994
# Epoch 12: val_accuracy improved from 0.98842 to 0.98850, saving model to best_model.h5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0613 - val_accuracy: 0.9885 - lr: 8.0000e-05
# Epoch 13/25
# 371/375 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9993
# Epoch 13: val_accuracy did not improve from 0.98850
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0615 - val_accuracy: 0.9885 - lr: 1.6000e-05
# Epoch 14/25
# 375/375 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 14: val_accuracy improved from 0.98850 to 0.98858, saving model to best_model.h5
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0617 - val_accuracy: 0.9886 - lr: 1.6000e-05
# Epoch 15/25
# 365/375 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9993
# Epoch 15: val_accuracy did not improve from 0.98858
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0618 - val_accuracy: 0.9886 - lr: 1.0000e-05
# Epoch 16/25
# 369/375 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 16: val_accuracy did not improve from 0.98858
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0620 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 17/25
# 370/375 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 17: val_accuracy did not improve from 0.98858
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0621 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 18/25
# 358/375 [===========================>..] - ETA: 0s - loss: 0.0025 - accuracy: 0.9994
# Epoch 18: val_accuracy did not improve from 0.98858
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0623 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 19/25
# 369/375 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 19: val_accuracy did not improve from 0.98858
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0625 - val_accuracy: 0.9884 - lr: 1.0000e-05
# Epoch 20/25
# 366/375 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9994
# Epoch 20: val_accuracy did not improve from 0.98858
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0627 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 21/25
# 365/375 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 21: val_accuracy did not improve from 0.98858
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0629 - val_accuracy: 0.9884 - lr: 1.0000e-05
# Epoch 22/25
# 370/375 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 22: val_accuracy did not improve from 0.98858
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0631 - val_accuracy: 0.9884 - lr: 1.0000e-05
# Epoch 23/25
# 372/375 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 23: val_accuracy did not improve from 0.98858
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0633 - val_accuracy: 0.9884 - lr: 1.0000e-05
# Epoch 24/25
# 374/375 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 24: val_accuracy did not improve from 0.98858
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0636 - val_accuracy: 0.9883 - lr: 1.0000e-05
# Epoch 25/25
# 370/375 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 25: val_accuracy did not improve from 0.98858
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0637 - val_accuracy: 0.9883 - lr: 1.0000e-05
# Test loss: 5.12
# Test accuracy: 98.92

# %% [markdown]
# ## Ejercicio:
#
# Probar las técnicas presentadas en la práctica 1 (dropout, batchnorm y aumento de datos) para obtener un acierto en test > 99%, incluso mejor que la obtenida con redes MLP.
