# %% [markdown]
# # S1. Red convolucional para MNIST

# %% [markdown]
# Como en la anterior práctica, primero importamos el conjunto de MNIST y lo normalizamos, pero sin convertir las imágenes en vectores unidimensionales, ya que vamos a trabajar con redes convolucionales que explotan la estructura 2D de las imágenes.

# %%
## Importar y normalizar datos

from tensorflow import keras
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

print('training set', x_train.shape)
print('test set', x_test.shape)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize [0..255]-->[0..1]
x_train /= 255
x_test /= 255

# convert class vectors to binary class matrices
num_classes=10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

print('training set', x_train.shape)
print('val set', x_val.shape)
# Out:
# training set (60000, 28, 28)
# test set (10000, 28, 28)
# training set (48000, 28, 28)
# val set (12000, 28, 28)

# %% [markdown]
# ## Modelo base
#  Partiremos de una topología base que toma la red MLP de la última sesión de la primera práctica (dos capas densas de 1024 neuronas), y le incorpora un par de capas convolucionales cada una seguida por average pooling inspirada en la arquitectura LeNet (1998) propuesta por Yann LeCun para MNIST.

# %%
from keras import Sequential
from keras.layers import Input, Conv2D, AveragePooling2D, Flatten, Dense
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

model = Sequential()

model.add(Input((28,28,1)))
model.add(Conv2D(filters=6, kernel_size=(5,5), activation='relu', input_shape=(28,28,1)))
model.add(AveragePooling2D(pool_size=(2,2), strides=2))
model.add(Conv2D(filters=16, kernel_size=(5,5), activation='relu'))
model.add(AveragePooling2D(pool_size=(2,2), strides=2))
model.add(Flatten())
model.add(Dense(units=1024, activation='relu'))
model.add(Dense(units=1024, activation='relu'))
model.add(Dense(units=10, activation = 'softmax'))

opt=Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy'])

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001)
checkpoint = ModelCheckpoint(filepath='best_model.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

epochs=25
batch_size=128
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val, y_val),
                    callbacks=[reduce_lr,checkpoint])  

## Cargar el mejor modelo y evaluarlo con el test set
model = keras.models.load_model('best_model.h5')
score = model.evaluate(x_test, y_test, verbose=0)
print(f'Test loss: {score[0]*100:.2f}')
print(f'Test accuracy: {score[1]*100:.2f}')
# Out:
# Epoch 1/25
# 369/375 [============================>.] - ETA: 0s - loss: 0.2812 - accuracy: 0.9181
# Epoch 1: val_accuracy improved from -inf to 0.97050, saving model to best_model.h5
# 375/375 [==============================] - 3s 5ms/step - loss: 0.2782 - accuracy: 0.9189 - val_loss: 0.0968 - val_accuracy: 0.9705 - lr: 0.0010
# Epoch 2/25
# 375/375 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9773
# Epoch 2: val_accuracy improved from 0.97050 to 0.98158, saving model to best_model.h5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0738 - accuracy: 0.9773 - val_loss: 0.0622 - val_accuracy: 0.9816 - lr: 0.0010
# Epoch 3/25
# 374/375 [============================>.] - ETA: 0s - loss: 0.0526 - accuracy: 0.9838
# Epoch 3: val_accuracy improved from 0.98158 to 0.98533, saving model to best_model.h5
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0525 - accuracy: 0.9838 - val_loss: 0.0488 - val_accuracy: 0.9853 - lr: 0.0010
# Epoch 4/25
# 366/375 [============================>.] - ETA: 0s - loss: 0.0422 - accuracy: 0.9874
# Epoch 4: val_accuracy improved from 0.98533 to 0.98783, saving model to best_model.h5
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0417 - accuracy: 0.9875 - val_loss: 0.0467 - val_accuracy: 0.9878 - lr: 0.0010
# Epoch 5/25
# 368/375 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9894
# Epoch 5: val_accuracy did not improve from 0.98783
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0334 - accuracy: 0.9894 - val_loss: 0.0441 - val_accuracy: 0.9869 - lr: 0.0010
# Epoch 6/25
# 366/375 [============================>.] - ETA: 0s - loss: 0.0274 - accuracy: 0.9911
# Epoch 6: val_accuracy improved from 0.98783 to 0.98917, saving model to best_model.h5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0277 - accuracy: 0.9910 - val_loss: 0.0422 - val_accuracy: 0.9892 - lr: 0.0010
# Epoch 7/25
# 374/375 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 0.9923
# Epoch 7: val_accuracy did not improve from 0.98917
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0232 - accuracy: 0.9923 - val_loss: 0.0425 - val_accuracy: 0.9876 - lr: 0.0010
# Epoch 8/25
# 369/375 [============================>.] - ETA: 0s - loss: 0.0192 - accuracy: 0.9938
# Epoch 8: val_accuracy improved from 0.98917 to 0.99050, saving model to best_model.h5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0193 - accuracy: 0.9938 - val_loss: 0.0364 - val_accuracy: 0.9905 - lr: 0.0010
# Epoch 9/25
# 373/375 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9948
# Epoch 9: val_accuracy did not improve from 0.99050
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0176 - accuracy: 0.9948 - val_loss: 0.0389 - val_accuracy: 0.9900 - lr: 0.0010
# Epoch 10/25
# 371/375 [============================>.] - ETA: 0s - loss: 0.0157 - accuracy: 0.9948
# Epoch 10: val_accuracy did not improve from 0.99050
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0550 - val_accuracy: 0.9860 - lr: 0.0010
# Epoch 11/25
# 366/375 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9984
# Epoch 11: val_accuracy did not improve from 0.99050
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.0360 - val_accuracy: 0.9904 - lr: 2.0000e-04
# Epoch 12/25
# 373/375 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9992
# Epoch 12: val_accuracy improved from 0.99050 to 0.99150, saving model to best_model.h5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0379 - val_accuracy: 0.9915 - lr: 2.0000e-04
# Epoch 13/25
# 370/375 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 13: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0389 - val_accuracy: 0.9909 - lr: 2.0000e-04
# Epoch 14/25
# 366/375 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9998
# Epoch 14: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0389 - val_accuracy: 0.9914 - lr: 4.0000e-05
# Epoch 15/25
# 367/375 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 15: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0392 - val_accuracy: 0.9912 - lr: 4.0000e-05
# Epoch 16/25
# 375/375 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9999
# Epoch 16: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.0393 - val_accuracy: 0.9912 - lr: 1.0000e-05
# Epoch 17/25
# 365/375 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 17: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0395 - val_accuracy: 0.9912 - lr: 1.0000e-05
# Epoch 18/25
# 366/375 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999
# Epoch 18: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0397 - val_accuracy: 0.9913 - lr: 1.0000e-05
# Epoch 19/25
# 375/375 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 19: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0400 - val_accuracy: 0.9912 - lr: 1.0000e-05
# Epoch 20/25
# 373/375 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 20: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0403 - val_accuracy: 0.9911 - lr: 1.0000e-05
# Epoch 21/25
# 367/375 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9999
# Epoch 21: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.0405 - val_accuracy: 0.9912 - lr: 1.0000e-05
# Epoch 22/25
# 375/375 [==============================] - ETA: 0s - loss: 9.8734e-04 - accuracy: 0.9999
# Epoch 22: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 9.8734e-04 - accuracy: 0.9999 - val_loss: 0.0407 - val_accuracy: 0.9912 - lr: 1.0000e-05
# Epoch 23/25
# 374/375 [============================>.] - ETA: 0s - loss: 9.6023e-04 - accuracy: 0.9999
# Epoch 23: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 9.5804e-04 - accuracy: 0.9999 - val_loss: 0.0411 - val_accuracy: 0.9912 - lr: 1.0000e-05
# Epoch 24/25
# 370/375 [============================>.] - ETA: 0s - loss: 9.2953e-04 - accuracy: 0.9999
# Epoch 24: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 9.2578e-04 - accuracy: 0.9999 - val_loss: 0.0415 - val_accuracy: 0.9913 - lr: 1.0000e-05
# Epoch 25/25
# 365/375 [============================>.] - ETA: 0s - loss: 8.8677e-04 - accuracy: 0.9999
# Epoch 25: val_accuracy did not improve from 0.99150
# 375/375 [==============================] - 2s 5ms/step - loss: 8.8049e-04 - accuracy: 0.9999 - val_loss: 0.0418 - val_accuracy: 0.9912 - lr: 1.0000e-05
# Test loss: 3.52
# Test accuracy: 99.08

# %% [markdown]
# ## Ejercicio:
#
# Probar las técnicas presentadas en la práctica 1 (dropout, batchnorm y aumento de datos) para obtener un acierto en test > 99%, incluso mejor que la obtenida con redes MLP.
