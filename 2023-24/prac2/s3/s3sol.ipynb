# %% [markdown]
# # S3. Fine-tuning de modelo pre-entrenado InceptionResNetV2 para la clasificación de CIFAR-10
# Este cuaderno realiza un fine-tuning del [modelo InceptionResNetV2](https://keras.io/api/applications/inceptionresnetv2/) pre-entrenado con la base de datos de imágenes [ImageNet](https://www.image-net.org) para la clasificación de CIFAR-10.

# %% [markdown]
# ### Carga de datos
# La utilización de una red pre-entrenada conlleva preprocesar nuestros datos con el mismo preproceso que se empleó para los datos de entrenamiento de la red pre-entrenada. En el caso de la red Inception V3, las imágenes necesitan, entre otras cosas, ser redimensionadas a 299 x 299. Si realizamos este preproceso para nuestro conjunto de entrenamiento, esto requeriría aproximadamente 40GB, por lo que es conveniente realizar este preproceso bajo demanda. Es decir, aplicaremos el preproceso para cada batch en el momento que vaya a ser utilizado.
#
# La aplicación de este preproceso bajo demanda está ya implementado en el módulo [tensorflow_datasets](https://www.tensorflow.org/datasets), así que en esta sesión cargaremos y manipularemos CIFAR-10 como un objeto [Dataset](https://www.tensorflow.org/api_docs/python/tf/data/Dataset) utilizando este módulo.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
train_size = len(train_data)

# %% [markdown]
# ### Preproceso
#
# Primero definimos una función que aplica el preproceso necesario a una muestra de entrenamiento (imagen, etiqueta de clase). Esto incluye redimensionar la imagen a 299 x 299, el preproceso específico de la red InceptionV3 y convertir la etiqueta de clase a one-hot encoding.

# %%
from keras.applications.inception_resnet_v2 import preprocess_input

img_size = (299, 299)
num_classes = 10

def preprocess(image, label):
    image = tf.image.resize(image, img_size)
    image = tf.cast(image, tf.float32)
    image = preprocess_input(image)
    label = tf.one_hot(label, num_classes)
    return image, label

# %% [markdown]
# A continuación indicamos que la función anteriormente definida se aplicará a cada imagen cuando sea necesario. Para ello utilizamos la función [map()](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#map) del objeto [Dataset](https://www.tensorflow.org/api_docs/python/tf/data/Dataset) y le pasamos como parámetro la función de preproceso que queremos que sea aplique a cada muestra del conjunto de datos.

# %%
train_data = train_data.map(preprocess)
test_data = test_data.map(preprocess)

# %% [markdown]
# Las funciones [take()](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#take) y [skip()](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#skip) combinadas permiten definir los conjuntos de entrenamiento y validación como nuevos Datasets.

# %%
train_size = int(0.8 * train_size)
train_dataset = train_data.take(train_size)
val_dataset = train_data.skip(train_size)
test_dataset = test_data

print(len(train_dataset),len(val_dataset))
# Out:
# 40000 10000

# %% [markdown]
# ### Carga del modelo pre-entrenado
#
# Seguidamente procedemos con la carga del modelo Inception V3 con los pesos resultantes de entrenarlo con la base de datos Imagenet, pero no queremos que el modelo incluya la capa de salida (include_top=False) que por defecto es una softmax de 1000 clases.

# %%
from keras.applications.inception_resnet_v2 import InceptionResNetV2

model = InceptionResNetV2(input_shape=img_size + (3,),include_top=False, weights='imagenet')
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 338s 2us/step
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 149, 149, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 149, 149, 32)         96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 149, 149, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 147, 147, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 147, 147, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 147, 147, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 147, 147, 64)         18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 147, 147, 64)         192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 147, 147, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 73, 73, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 73, 73, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 73, 73, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 73, 73, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 71, 71, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 71, 71, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 71, 71, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 35, 35, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 35, 35, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 35, 35, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 35, 35, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 35, 35, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 35, 35, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 35, 35, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 35, 35, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 35, 35, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 35, 35, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 35, 35, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 35, 35, 96)           18432     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 35, 35, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 35, 35, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 35, 35, 64)           12288     ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 35, 35, 96)           288       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 35, 35, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 35, 35, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 35, 35, 64)           192       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 35, 35, 96)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 35, 35, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 35, 35, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed_5b (Concatenate)      (None, 35, 35, 320)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_15 (Ba  (None, 35, 35, 32)           96        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 35, 35, 32)           96        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 35, 35, 48)           144       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_16[0][0]']
#
#  batch_normalization_12 (Ba  (None, 35, 35, 32)           96        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 35, 35, 32)           96        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 35, 35, 64)           192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  block35_1_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_12[0][0]',
#  te)                                                                 'activation_14[0][0]',
#                                                                      'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer (Custom  (None, 35, 35, 320)          0         ['mixed_5b[0][0]',
#  ScaleLayer)                                                         'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (Ba  (None, 35, 35, 32)           96        ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_21[0][0]']
#
#  batch_normalization_19 (Ba  (None, 35, 35, 32)           96        ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 35, 35, 48)           144       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_22[0][0]']
#
#  batch_normalization_18 (Ba  (None, 35, 35, 32)           96        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 35, 35, 32)           96        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 35, 35, 64)           192       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  block35_2_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_18[0][0]',
#  te)                                                                 'activation_20[0][0]',
#                                                                      'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_1 (Cust  (None, 35, 35, 320)          0         ['block35_1_ac[0][0]',
#  omScaleLayer)                                                       'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_1[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (Ba  (None, 35, 35, 32)           96        ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_27[0][0]']
#
#  batch_normalization_25 (Ba  (None, 35, 35, 32)           96        ['conv2d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 35, 35, 48)           144       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_28[0][0]']
#
#  batch_normalization_24 (Ba  (None, 35, 35, 32)           96        ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 35, 35, 32)           96        ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 35, 35, 64)           192       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  block35_3_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_24[0][0]',
#  te)                                                                 'activation_26[0][0]',
#                                                                      'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_2 (Cust  (None, 35, 35, 320)          0         ['block35_2_ac[0][0]',
#  omScaleLayer)                                                       'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_2[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (Ba  (None, 35, 35, 32)           96        ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_33[0][0]']
#
#  batch_normalization_31 (Ba  (None, 35, 35, 32)           96        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 35, 35, 48)           144       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 35, 35, 32)           96        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 35, 35, 32)           96        ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 35, 35, 64)           192       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  block35_4_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_30[0][0]',
#  te)                                                                 'activation_32[0][0]',
#                                                                      'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_3 (Cust  (None, 35, 35, 320)          0         ['block35_3_ac[0][0]',
#  omScaleLayer)                                                       'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (Ba  (None, 35, 35, 32)           96        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_39[0][0]']
#
#  batch_normalization_37 (Ba  (None, 35, 35, 32)           96        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 35, 35, 48)           144       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_40[0][0]']
#
#  batch_normalization_36 (Ba  (None, 35, 35, 32)           96        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 35, 35, 32)           96        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 35, 35, 64)           192       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  block35_5_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_36[0][0]',
#  te)                                                                 'activation_38[0][0]',
#                                                                      'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_4 (Cust  (None, 35, 35, 320)          0         ['block35_4_ac[0][0]',
#  omScaleLayer)                                                       'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_4[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (Ba  (None, 35, 35, 32)           96        ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_45[0][0]']
#
#  batch_normalization_43 (Ba  (None, 35, 35, 32)           96        ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 35, 35, 48)           144       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 35, 35, 32)           96        ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 35, 35, 32)           96        ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 35, 35, 64)           192       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  block35_6_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_42[0][0]',
#  te)                                                                 'activation_44[0][0]',
#                                                                      'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_5 (Cust  (None, 35, 35, 320)          0         ['block35_5_ac[0][0]',
#  omScaleLayer)                                                       'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_5[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (Ba  (None, 35, 35, 32)           96        ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_51[0][0]']
#
#  batch_normalization_49 (Ba  (None, 35, 35, 32)           96        ['conv2d_49[0][0]']
#  tchNormalization)
# ...
#
#  batch_normalization_187 (B  (None, 8, 8, 192)            576       ['conv2d_187[0][0]']
#  atchNormalization)
#
#  batch_normalization_190 (B  (None, 8, 8, 256)            768       ['conv2d_190[0][0]']
#  atchNormalization)
#
#  activation_187 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_187[0][0
#  )                                                                  ]']
#
#  activation_190 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_190[0][0
#  )                                                                  ]']
#
#  block8_7_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_187[0][0]',
#  e)                                                                  'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_36 (Cus  (None, 8, 8, 2080)           0         ['block8_6_ac[0][0]',
#  tomScaleLayer)                                                      'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_36[0][0]'
#                                                                     ]
#
#  conv2d_192 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (B  (None, 8, 8, 192)            576       ['conv2d_192[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  conv2d_193 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_192[0][0]']
#
#  batch_normalization_193 (B  (None, 8, 8, 224)            672       ['conv2d_193[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  conv2d_191 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_193[0][0]']
#
#  batch_normalization_191 (B  (None, 8, 8, 192)            576       ['conv2d_191[0][0]']
#  atchNormalization)
#
#  batch_normalization_194 (B  (None, 8, 8, 256)            768       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  activation_194 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_191[0][0]',
#  e)                                                                  'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_37 (Cus  (None, 8, 8, 2080)           0         ['block8_7_ac[0][0]',
#  tomScaleLayer)                                                      'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_37[0][0]'
#                                                                     ]
#
#  conv2d_196 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (B  (None, 8, 8, 192)            576       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv2d_197 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_196[0][0]']
#
#  batch_normalization_197 (B  (None, 8, 8, 224)            672       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  activation_197 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  conv2d_195 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_197[0][0]']
#
#  batch_normalization_195 (B  (None, 8, 8, 192)            576       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (None, 8, 8, 256)            768       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  activation_195 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  block8_9_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_195[0][0]',
#  e)                                                                  'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_38 (Cus  (None, 8, 8, 2080)           0         ['block8_8_ac[0][0]',
#  tomScaleLayer)                                                      'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_38[0][0]'
#                                                                     ]
#
#  conv2d_200 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (B  (None, 8, 8, 192)            576       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_200[0][0]']
#
#  batch_normalization_201 (B  (None, 8, 8, 224)            672       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  conv2d_199 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  conv2d_202 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_201[0][0]']
#
#  batch_normalization_199 (B  (None, 8, 8, 192)            576       ['conv2d_199[0][0]']
#  atchNormalization)
#
#  batch_normalization_202 (B  (None, 8, 8, 256)            768       ['conv2d_202[0][0]']
#  atchNormalization)
#
#  activation_199 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  block8_10_mixed (Concatena  (None, 8, 8, 448)            0         ['activation_199[0][0]',
#  te)                                                                 'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 8, 8, 2080)           933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_39 (Cus  (None, 8, 8, 2080)           0         ['block8_9_ac[0][0]',
#  tomScaleLayer)                                                      'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 8, 8, 1536)           3194880   ['custom_scale_layer_39[0][0]'
#                                                                     ]
#
#  conv_7b_bn (BatchNormaliza  (None, 8, 8, 1536)           4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 8, 8, 1536)           0         ['conv_7b_bn[0][0]']
#
# ==================================================================================================
# Total params: 54336736 (207.28 MB)
# Trainable params: 54276192 (207.05 MB)
# Non-trainable params: 60544 (236.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Preparación del modelo pre-entrenado
#
# Vamos a preparar la red Inception V3 para ser entrenada (fine-tuning) con CIFAR-10. Dado el número de parámetros de este modelo (21M), nos limitaremos a utilizarlo con los valores por defecto y añadiremos una capa GlobalAveragePooling + MLP seguida de una softmax de 10 neuronas (10 clases) acorde a CIFAR-10 que sí que entrenaremos.

# %%
from keras.layers import GlobalAveragePooling2D, Dense, Dropout
from keras.models import Model

for layer in model.layers:
    layer.trainable = False

x = GlobalAveragePooling2D()(model.output)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=model.input, outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 149, 149, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 149, 149, 32)         96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 149, 149, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 147, 147, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 147, 147, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 147, 147, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 147, 147, 64)         18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 147, 147, 64)         192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 147, 147, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 73, 73, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 73, 73, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 73, 73, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 73, 73, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 71, 71, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 71, 71, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 71, 71, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 35, 35, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 35, 35, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 35, 35, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 35, 35, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 35, 35, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 35, 35, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 35, 35, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 35, 35, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 35, 35, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 35, 35, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 35, 35, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 35, 35, 96)           18432     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 35, 35, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 35, 35, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 35, 35, 64)           12288     ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 35, 35, 96)           288       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 35, 35, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 35, 35, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 35, 35, 64)           192       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 35, 35, 96)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 35, 35, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 35, 35, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed_5b (Concatenate)      (None, 35, 35, 320)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_15 (Ba  (None, 35, 35, 32)           96        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 35, 35, 32)           96        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 35, 35, 48)           144       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_16[0][0]']
#
#  batch_normalization_12 (Ba  (None, 35, 35, 32)           96        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 35, 35, 32)           96        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 35, 35, 64)           192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  block35_1_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_12[0][0]',
#  te)                                                                 'activation_14[0][0]',
#                                                                      'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer (Custom  (None, 35, 35, 320)          0         ['mixed_5b[0][0]',
#  ScaleLayer)                                                         'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (Ba  (None, 35, 35, 32)           96        ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_21[0][0]']
#
#  batch_normalization_19 (Ba  (None, 35, 35, 32)           96        ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 35, 35, 48)           144       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_22[0][0]']
#
#  batch_normalization_18 (Ba  (None, 35, 35, 32)           96        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 35, 35, 32)           96        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 35, 35, 64)           192       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  block35_2_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_18[0][0]',
#  te)                                                                 'activation_20[0][0]',
#                                                                      'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_1 (Cust  (None, 35, 35, 320)          0         ['block35_1_ac[0][0]',
#  omScaleLayer)                                                       'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_1[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (Ba  (None, 35, 35, 32)           96        ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_27[0][0]']
#
#  batch_normalization_25 (Ba  (None, 35, 35, 32)           96        ['conv2d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 35, 35, 48)           144       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_28[0][0]']
#
#  batch_normalization_24 (Ba  (None, 35, 35, 32)           96        ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 35, 35, 32)           96        ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 35, 35, 64)           192       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  block35_3_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_24[0][0]',
#  te)                                                                 'activation_26[0][0]',
#                                                                      'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_2 (Cust  (None, 35, 35, 320)          0         ['block35_2_ac[0][0]',
#  omScaleLayer)                                                       'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_2[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (Ba  (None, 35, 35, 32)           96        ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_33[0][0]']
#
#  batch_normalization_31 (Ba  (None, 35, 35, 32)           96        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 35, 35, 48)           144       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 35, 35, 32)           96        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 35, 35, 32)           96        ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 35, 35, 64)           192       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  block35_4_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_30[0][0]',
#  te)                                                                 'activation_32[0][0]',
#                                                                      'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_3 (Cust  (None, 35, 35, 320)          0         ['block35_3_ac[0][0]',
#  omScaleLayer)                                                       'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (Ba  (None, 35, 35, 32)           96        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_39[0][0]']
#
#  batch_normalization_37 (Ba  (None, 35, 35, 32)           96        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 35, 35, 48)           144       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_40[0][0]']
#
#  batch_normalization_36 (Ba  (None, 35, 35, 32)           96        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 35, 35, 32)           96        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 35, 35, 64)           192       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  block35_5_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_36[0][0]',
#  te)                                                                 'activation_38[0][0]',
#                                                                      'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_4 (Cust  (None, 35, 35, 320)          0         ['block35_4_ac[0][0]',
#  omScaleLayer)                                                       'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_4[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (Ba  (None, 35, 35, 32)           96        ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_45[0][0]']
#
#  batch_normalization_43 (Ba  (None, 35, 35, 32)           96        ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 35, 35, 48)           144       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 35, 35, 32)           96        ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 35, 35, 32)           96        ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 35, 35, 64)           192       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  block35_6_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_42[0][0]',
#  te)                                                                 'activation_44[0][0]',
#                                                                      'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_5 (Cust  (None, 35, 35, 320)          0         ['block35_5_ac[0][0]',
#  omScaleLayer)                                                       'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_5[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (Ba  (None, 35, 35, 32)           96        ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_51[0][0]']
#
#  batch_normalization_49 (Ba  (None, 35, 35, 32)           96        ['conv2d_49[0][0]']
#  tchNormalization)
#
#  batch_normalization_52 (Ba  (None, 35, 35, 48)           144       ['conv2d_52[0][0]']
# ...
#  activation_190 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_190[0][0
#  )                                                                  ]']
#
#  block8_7_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_187[0][0]',
#  e)                                                                  'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_36 (Cus  (None, 8, 8, 2080)           0         ['block8_6_ac[0][0]',
#  tomScaleLayer)                                                      'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_36[0][0]'
#                                                                     ]
#
#  conv2d_192 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (B  (None, 8, 8, 192)            576       ['conv2d_192[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  conv2d_193 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_192[0][0]']
#
#  batch_normalization_193 (B  (None, 8, 8, 224)            672       ['conv2d_193[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  conv2d_191 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_193[0][0]']
#
#  batch_normalization_191 (B  (None, 8, 8, 192)            576       ['conv2d_191[0][0]']
#  atchNormalization)
#
#  batch_normalization_194 (B  (None, 8, 8, 256)            768       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  activation_194 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_191[0][0]',
#  e)                                                                  'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_37 (Cus  (None, 8, 8, 2080)           0         ['block8_7_ac[0][0]',
#  tomScaleLayer)                                                      'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_37[0][0]'
#                                                                     ]
#
#  conv2d_196 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (B  (None, 8, 8, 192)            576       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv2d_197 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_196[0][0]']
#
#  batch_normalization_197 (B  (None, 8, 8, 224)            672       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  activation_197 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  conv2d_195 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_197[0][0]']
#
#  batch_normalization_195 (B  (None, 8, 8, 192)            576       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (None, 8, 8, 256)            768       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  activation_195 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  block8_9_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_195[0][0]',
#  e)                                                                  'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_38 (Cus  (None, 8, 8, 2080)           0         ['block8_8_ac[0][0]',
#  tomScaleLayer)                                                      'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_38[0][0]'
#                                                                     ]
#
#  conv2d_200 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (B  (None, 8, 8, 192)            576       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_200[0][0]']
#
#  batch_normalization_201 (B  (None, 8, 8, 224)            672       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  conv2d_199 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  conv2d_202 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_201[0][0]']
#
#  batch_normalization_199 (B  (None, 8, 8, 192)            576       ['conv2d_199[0][0]']
#  atchNormalization)
#
#  batch_normalization_202 (B  (None, 8, 8, 256)            768       ['conv2d_202[0][0]']
#  atchNormalization)
#
#  activation_199 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  block8_10_mixed (Concatena  (None, 8, 8, 448)            0         ['activation_199[0][0]',
#  te)                                                                 'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 8, 8, 2080)           933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_39 (Cus  (None, 8, 8, 2080)           0         ['block8_9_ac[0][0]',
#  tomScaleLayer)                                                      'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 8, 8, 1536)           3194880   ['custom_scale_layer_39[0][0]'
#                                                                     ]
#
#  conv_7b_bn (BatchNormaliza  (None, 8, 8, 1536)           4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 8, 8, 1536)           0         ['conv_7b_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1536)                 0         ['conv_7b_ac[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)                 1573888   ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 1024)                 0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 10)                   10250     ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 55920874 (213.32 MB)
# Trainable params: 1584138 (6.04 MB)
# Non-trainable params: 54336736 (207.28 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# Compilamos el modelo con los mismos parámetros que en sesiones anteriores.

# %%
from keras.optimizers import Adam

opt=Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy'])

# %% [markdown]
# Entrenamos el modelo utilizando los conjuntos de datos organizado en batches y que son cargados en memoria dinámicamente.

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.models import load_model

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001)
checkpoint = ModelCheckpoint(filepath='best_model.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

epochs=10
batch_size=32
train_dataset_batched = train_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
val_dataset_batched = val_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
history = model.fit(train_dataset_batched,
                    epochs=epochs,
                    verbose=1,
                    validation_data=val_dataset_batched,
                    callbacks=[reduce_lr,checkpoint])
# Out:
# Epoch 1/10
# 2023-12-09 11:11:21.402129: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 2023-12-09 11:11:21.453250: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:225] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2023-12-09 11:11:21.453265: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:228] Used ptxas at ptxas
# 2023-12-09 11:11:21.453302: W external/local_xla/xla/stream_executor/gpu/redzone_allocator.cc:322] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-12-09 11:11:25.524817: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2023-12-09 11:11:27.349495: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2023-12-09 11:11:27.350607: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2023-12-09 11:11:27.351024: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2023-12-09 11:11:27.351217: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2023-12-09 11:11:27.352056: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2023-12-09 11:11:27.352338: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2023-12-09 11:11:27.352356: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2023-12-09 11:11:27.352590: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2023-12-09 11:11:27.352816: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2023-12-09 11:11:27.620795: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f1ac8ff72b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-09 11:11:27.620814: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2023-12-09 11:11:27.624798: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1702116687.663331   14287 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4452 - accuracy: 0.8561
# 2023-12-09 11:15:30.216502: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# Epoch 1: val_accuracy improved from -inf to 0.89370, saving model to best_model.h5
# /home/jorcisai/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1250/1250 [==============================] - 322s 248ms/step - loss: 0.4452 - accuracy: 0.8561 - val_loss: 0.3189 - val_accuracy: 0.8937 - lr: 0.0010
# Epoch 2/10
# 1250/1250 [==============================] - ETA: 0s - loss: 0.3506 - accuracy: 0.8848
# Epoch 2: val_accuracy improved from 0.89370 to 0.90590, saving model to best_model.h5
# 1250/1250 [==============================] - 304s 244ms/step - loss: 0.3506 - accuracy: 0.8848 - val_loss: 0.2840 - val_accuracy: 0.9059 - lr: 0.0010
# Epoch 3/10
# 1250/1250 [==============================] - ETA: 0s - loss: 0.3270 - accuracy: 0.8901
# Epoch 3: val_accuracy improved from 0.90590 to 0.90730, saving model to best_model.h5
# 1250/1250 [==============================] - 304s 243ms/step - loss: 0.3270 - accuracy: 0.8901 - val_loss: 0.2777 - val_accuracy: 0.9073 - lr: 0.0010
# Epoch 4/10
# 1250/1250 [==============================] - ETA: 0s - loss: 0.3107 - accuracy: 0.8973
# Epoch 4: val_accuracy did not improve from 0.90730
# 1250/1250 [==============================] - 304s 243ms/step - loss: 0.3107 - accuracy: 0.8973 - val_loss: 0.2869 - val_accuracy: 0.9053 - lr: 0.0010
# Epoch 5/10
# 1250/1250 [==============================] - ETA: 0s - loss: 0.2966 - accuracy: 0.9007
# Epoch 5: val_accuracy improved from 0.90730 to 0.91270, saving model to best_model.h5
# 1250/1250 [==============================] - 304s 243ms/step - loss: 0.2966 - accuracy: 0.9007 - val_loss: 0.2647 - val_accuracy: 0.9127 - lr: 0.0010
# Epoch 6/10
# 1250/1250 [==============================] - ETA: 0s - loss: 0.2893 - accuracy: 0.9018
# Epoch 6: val_accuracy did not improve from 0.91270
# 1250/1250 [==============================] - 303s 242ms/step - loss: 0.2893 - accuracy: 0.9018 - val_loss: 0.2777 - val_accuracy: 0.9081 - lr: 0.0010
# Epoch 7/10
# 1250/1250 [==============================] - ETA: 0s - loss: 0.2788 - accuracy: 0.9060
# Epoch 7: val_accuracy did not improve from 0.91270
# 1250/1250 [==============================] - 303s 242ms/step - loss: 0.2788 - accuracy: 0.9060 - val_loss: 0.2737 - val_accuracy: 0.9100 - lr: 0.0010
# Epoch 8/10
# 1250/1250 [==============================] - ETA: 0s - loss: 0.2245 - accuracy: 0.9235
# Epoch 8: val_accuracy improved from 0.91270 to 0.92140, saving model to best_model.h5
# 1250/1250 [==============================] - 304s 243ms/step - loss: 0.2245 - accuracy: 0.9235 - val_loss: 0.2437 - val_accuracy: 0.9214 - lr: 2.0000e-04
# Epoch 9/10
# 1250/1250 [==============================] - ETA: 0s - loss: 0.2109 - accuracy: 0.9282
# Epoch 9: val_accuracy did not improve from 0.92140
# 1250/1250 [==============================] - 303s 242ms/step - loss: 0.2109 - accuracy: 0.9282 - val_loss: 0.2453 - val_accuracy: 0.9209 - lr: 2.0000e-04
# Epoch 10/10
# 1250/1250 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9298
# Epoch 10: val_accuracy improved from 0.92140 to 0.92200, saving model to best_model.h5
# 1250/1250 [==============================] - 304s 243ms/step - loss: 0.2022 - accuracy: 0.9298 - val_loss: 0.2429 - val_accuracy: 0.9220 - lr: 2.0000e-04

# %% [markdown]
# ### Cargar el mejor modelo y evaluarlo con el test set

# %%
model = load_model('best_model.h5')
test_dataset_batched = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
score = model.evaluate(test_dataset_batched, verbose=0)
print(f'Test loss: {score[0]*100:.2f}')
print(f'Test accuracy: {score[1]*100:.2f}')
# Out:
# Test loss: 25.86
# Test accuracy: 91.77

# %% [markdown]
# ### Aumento de datos
#
# En las sesiones anteriores, hemos utilizado la función [ImageDataGenerator](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator) para realizar el aumento de datos. Sin embargo, esta función no se recomienda para los nuevos desarrollos de código por estar obsoleta, y en su lugar se deben utilizar las [capas de preproceso](https://www.tensorflow.org/guide/keras/preprocessing_layers). Más concretamente, utilizaremos algunas de las [capas de preproceso de aumento de datos para imágenes](https://www.tensorflow.org/guide/keras/preprocessing_layers#image_data_augmentation).
#
# Añadiremos estas capas de aumento de datos antes del modelo Inception V3.

# %%
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout, RandomRotation, RandomTranslation, RandomZoom
from keras.models import Model

input_layer = Input(shape=img_size + (3,))

x = RandomRotation(factor=0.1, fill_mode='nearest')(input_layer)
x = RandomTranslation(height_factor=0.1, width_factor=0.1, fill_mode='nearest')(x)
x = RandomZoom(height_factor=0.2, fill_mode='nearest')(x)

inception_model = InceptionResNetV2(input_shape=img_size + (3,),include_top=False, weights='imagenet')

for layer in inception_model.layers:
    layer.trainable = False

x = inception_model(x)

x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(num_classes, activation='softmax')(x)

aug_model = Model(inputs=input_layer, outputs=output)

aug_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  random_rotation (RandomRot  (None, 299, 299, 3)       0
#  ation)
#
#  random_translation (Random  (None, 299, 299, 3)       0
#  Translation)
#
#  random_zoom (RandomZoom)    (None, 299, 299, 3)       0
#
#  inception_resnet_v2 (Funct  (None, 8, 8, 1536)        54336736
#  ional)
#
#  global_average_pooling2d_1  (None, 1536)              0
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 1024)              1573888
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 55920874 (213.32 MB)
# Trainable params: 1584138 (6.04 MB)
# Non-trainable params: 54336736 (207.28 MB)
# _________________________________________________________________

# %%
from keras.optimizers import Adam

opt=Adam(learning_rate=0.001)
aug_model.compile(loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy'])

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.models import load_model

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001)
checkpoint = ModelCheckpoint(filepath='best_model.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

epochs=20
batch_size=32
train_dataset_batched = train_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
val_dataset_batched = val_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
history = aug_model.fit(train_dataset_batched,
                    epochs=epochs,
                    verbose=1,
                    validation_data=val_dataset_batched,
                    callbacks=[reduce_lr,checkpoint])
# Out:
# Epoch 1/20
# 2023-12-09 13:11:38.513772: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7988 - accuracy: 0.7282
# Epoch 1: val_accuracy improved from -inf to 0.88330, saving model to best_model.h5
# /home/jorcisai/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1250/1250 [==============================] - 317s 249ms/step - loss: 0.7988 - accuracy: 0.7282 - val_loss: 0.3452 - val_accuracy: 0.8833 - lr: 0.0010
# Epoch 2/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6816 - accuracy: 0.7674
# Epoch 2: val_accuracy improved from 0.88330 to 0.89410, saving model to best_model.h5
# 1250/1250 [==============================] - 308s 247ms/step - loss: 0.6816 - accuracy: 0.7674 - val_loss: 0.3238 - val_accuracy: 0.8941 - lr: 0.0010
# Epoch 3/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6502 - accuracy: 0.7777
# Epoch 3: val_accuracy improved from 0.89410 to 0.89970, saving model to best_model.h5
# 1250/1250 [==============================] - 308s 246ms/step - loss: 0.6502 - accuracy: 0.7777 - val_loss: 0.3055 - val_accuracy: 0.8997 - lr: 0.0010
# Epoch 4/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6346 - accuracy: 0.7829
# Epoch 4: val_accuracy did not improve from 0.89970
# 1250/1250 [==============================] - 308s 246ms/step - loss: 0.6346 - accuracy: 0.7829 - val_loss: 0.3269 - val_accuracy: 0.8891 - lr: 0.0010
# Epoch 5/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6241 - accuracy: 0.7870
# Epoch 5: val_accuracy improved from 0.89970 to 0.90010, saving model to best_model.h5
# 1250/1250 [==============================] - 308s 246ms/step - loss: 0.6241 - accuracy: 0.7870 - val_loss: 0.3033 - val_accuracy: 0.9001 - lr: 0.0010
# Epoch 6/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6141 - accuracy: 0.7922
# Epoch 6: val_accuracy improved from 0.90010 to 0.90880, saving model to best_model.h5
# 1250/1250 [==============================] - 309s 247ms/step - loss: 0.6141 - accuracy: 0.7922 - val_loss: 0.2792 - val_accuracy: 0.9088 - lr: 0.0010
# Epoch 7/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.5943 - accuracy: 0.7982
# Epoch 7: val_accuracy did not improve from 0.90880
# 1250/1250 [==============================] - 308s 247ms/step - loss: 0.5943 - accuracy: 0.7982 - val_loss: 0.2875 - val_accuracy: 0.9049 - lr: 0.0010
# Epoch 8/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.5932 - accuracy: 0.7978
# Epoch 8: val_accuracy did not improve from 0.90880
# 1250/1250 [==============================] - 309s 247ms/step - loss: 0.5932 - accuracy: 0.7978 - val_loss: 0.2856 - val_accuracy: 0.9069 - lr: 0.0010
# Epoch 9/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.5261 - accuracy: 0.8215
# Epoch 9: val_accuracy improved from 0.90880 to 0.91340, saving model to best_model.h5
# 1250/1250 [==============================] - 310s 248ms/step - loss: 0.5261 - accuracy: 0.8215 - val_loss: 0.2662 - val_accuracy: 0.9134 - lr: 2.0000e-04
# Epoch 10/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.5110 - accuracy: 0.8248
# Epoch 10: val_accuracy improved from 0.91340 to 0.91650, saving model to best_model.h5
# 1250/1250 [==============================] - 309s 247ms/step - loss: 0.5110 - accuracy: 0.8248 - val_loss: 0.2557 - val_accuracy: 0.9165 - lr: 2.0000e-04
# Epoch 11/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.5060 - accuracy: 0.8280
# Epoch 11: val_accuracy did not improve from 0.91650
# 1250/1250 [==============================] - 309s 247ms/step - loss: 0.5060 - accuracy: 0.8280 - val_loss: 0.2551 - val_accuracy: 0.9161 - lr: 2.0000e-04
# Epoch 12/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4963 - accuracy: 0.8281
# Epoch 12: val_accuracy did not improve from 0.91650
# 1250/1250 [==============================] - 309s 247ms/step - loss: 0.4963 - accuracy: 0.8281 - val_loss: 0.2578 - val_accuracy: 0.9135 - lr: 2.0000e-04
# Epoch 13/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4984 - accuracy: 0.8297
# Epoch 13: val_accuracy improved from 0.91650 to 0.91700, saving model to best_model.h5
# 1250/1250 [==============================] - 310s 248ms/step - loss: 0.4984 - accuracy: 0.8297 - val_loss: 0.2484 - val_accuracy: 0.9170 - lr: 2.0000e-04
# Epoch 14/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4946 - accuracy: 0.8313
# Epoch 14: val_accuracy improved from 0.91700 to 0.91740, saving model to best_model.h5
# 1250/1250 [==============================] - 310s 248ms/step - loss: 0.4946 - accuracy: 0.8313 - val_loss: 0.2524 - val_accuracy: 0.9174 - lr: 2.0000e-04
# Epoch 15/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4825 - accuracy: 0.8356
# Epoch 15: val_accuracy did not improve from 0.91740
# 1250/1250 [==============================] - 309s 247ms/step - loss: 0.4825 - accuracy: 0.8356 - val_loss: 0.2499 - val_accuracy: 0.9173 - lr: 2.0000e-04
# Epoch 16/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4730 - accuracy: 0.8392
# Epoch 16: val_accuracy improved from 0.91740 to 0.91850, saving model to best_model.h5
# 1250/1250 [==============================] - 309s 247ms/step - loss: 0.4730 - accuracy: 0.8392 - val_loss: 0.2465 - val_accuracy: 0.9185 - lr: 4.0000e-05
# Epoch 17/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4779 - accuracy: 0.8382
# Epoch 17: val_accuracy improved from 0.91850 to 0.91930, saving model to best_model.h5
# 1250/1250 [==============================] - 309s 247ms/step - loss: 0.4779 - accuracy: 0.8382 - val_loss: 0.2436 - val_accuracy: 0.9193 - lr: 4.0000e-05
# Epoch 18/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4676 - accuracy: 0.8378
# Epoch 18: val_accuracy did not improve from 0.91930
# 1250/1250 [==============================] - 309s 248ms/step - loss: 0.4676 - accuracy: 0.8378 - val_loss: 0.2461 - val_accuracy: 0.9192 - lr: 4.0000e-05
# Epoch 19/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4716 - accuracy: 0.8400
# Epoch 19: val_accuracy did not improve from 0.91930
# 1250/1250 [==============================] - 309s 247ms/step - loss: 0.4716 - accuracy: 0.8400 - val_loss: 0.2434 - val_accuracy: 0.9191 - lr: 4.0000e-05
# Epoch 20/20
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4680 - accuracy: 0.8400
# Epoch 20: val_accuracy did not improve from 0.91930
# 1250/1250 [==============================] - 309s 247ms/step - loss: 0.4680 - accuracy: 0.8400 - val_loss: 0.2432 - val_accuracy: 0.9193 - lr: 4.0000e-05

# %%
aug_model = load_model('best_model.h5')
test_dataset_batched = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
score = aug_model.evaluate(test_dataset_batched, verbose=0)
print(f'Test loss: {score[0]*100:.2f}')
print(f'Test accuracy: {score[1]*100:.2f}')
# Out:
# Test loss: 25.66
# Test accuracy: 91.18
